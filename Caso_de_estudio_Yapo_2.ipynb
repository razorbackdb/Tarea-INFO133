# %% [markdown]
# Este notebook está vinculado al caso de estudio "Yapo" (ver el [documento](https://docs.google.com/document/d/1SwhwMOyG7-cmzasDeisQZ_NzX5v2VoZ7--lI4UhJz_U/edit#heading=h.5qaqs0frqkx4) de presentación). Se busca construir una base de datos de anuncios en Los Rios recopilando algunos anuncios de Yapo.cl.
#
# En este notebook, ya tenemos la Base de Datos Yapo construida. Consultamos y visualizamos los datos.

# %%
#!pip install pyshp

# %%
import numpy as np
import pandas as pd
import shapefile as shp
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from pandas import DataFrame
import pandas as pd

sns.set(style="whitegrid", palette="pastel", color_codes=True)
sns.mpl.rc("figure", figsize=(12,6))

# %% [markdown]
# # 3. Consultas SQL
#
# - ¿Cuál es el precio promedio de los anuncios por categoría?
#
# - ¿Cuál es el número de anuncios por vendedor y por día?
#
# - ¿Insertar una columna “Perfil” en la tabla Vendedor. Los Vendedores que publicaron más de 5 anuncios en los últimos 7 días, tienen un perfil “Pro”, los otros se consideran “Personal”.
#
# - ¿Cuál es el precio promedio de los anuncios según el día de la semana (lunes, martes, miercoles, etc.)

# %%
import mysql.connector 

db_connection = mysql.connector.connect(user="root",host="localhost",password="root")
cursor = db_connection.cursor()

cursor.execute("use Yapo2")

# %%
#¿Cuál es el precio promedio de los anuncios por categoría?

sql = "SELECT categoria, avg(precio) FROM anuncio WHERE moneda=\"$\" GROUP BY categoria ORDER BY avg(precio) DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#                                     categoria     avg(precio)
# 0              Vendo - Comercial e industrial  222632000.0000
# 1                             Vendo - Oficina  111333333.3333
# 2                                Vendo - Casa  101286759.7493
# 3                             Vendo - Terreno   64879135.6972
# 4                        Vendo - Departamento   63364095.8938
# 5                  Buses, camiones y furgones   11299310.3448
# 6                     Autos, camionetas y 4x4    6434454.9255
# 7                             Otros vehículos    5322276.4894
# 8                          Arriendo - Terreno    4000000.0000
# 9                   Barcos, lanchas y aviones    3433000.0000
# 10                                      Motos    2709577.0335
# 11                            Arriendo - Casa    2039979.6798
# 12     Vendo - Estacionamiento, bodega u otro    1757545.4545
# 13        Negocios, maquinaria y construcción    1394903.2460
# 14  Arriendo - Estacionamiento, bodega u otro     725468.7500
# 15          Arriendo - Comercial e industrial     721587.3016
# 16                    Arriendo - Departamento     605380.3879
# 17                  Animales y sus accesorios     417827.4719
# 18                          Ofertas de empleo     375714.2029
# 19                  Otros artículos del hogar     362654.6324
# 20                         Arriendo - Oficina     339819.6721
# 21                               Busco empleo     277461.5385
# 22          Bicicletas, ciclismo y accesorios     242891.1111
# 23        Instrumentos musicales y accesorios     199345.1203
# 24                           Arriendo - Pieza     187583.3333
# 25                  Computadores y accesorios     186832.9103
# 26          Jardín, herramientas y exteriores     166753.6172
# 27          Celulares, teléfonos y accesorios     146876.5412
# 28                                    Muebles     140580.3582
# 29                            Salud y belleza     125484.1035
# 30           Arte, antigüedades y colecciones     124344.7628
# 31              Audio, TV, video y fotografía     108295.2463
# 32         Accesorios y piezas para vehículos     105499.2201
# 33                          Electrodomésticos     104354.6527
# 34               Arriendo de temporada - Casa     100000.0000
# 35             Arriendo de temporada - Cabaña      90000.0000
# 36         Consolas, videojuegos y accesorios      85802.1650
# 37                                  Servicios      79632.7593
# 38             Bolsos, bisutería y accesorios      61150.0573
# 39            Deportes, gimnasia y accesorios      54923.6859
# 40                          Hobbies y outdoor      53013.5676
# 41              Coches y artículos infantiles      49215.9605
# 42                            Otros productos      32465.3073
# 43       Arriendo de temporada - Departamento      29640.0000
# 44                                    Calzado      28443.8636
# 45            Música y películas (DVDs, etc.)      24397.8652
# 46                                   Juguetes      20967.5686
# 47                           Moda y vestuario      19835.8753
# 48              Vestuario futura mamá y niños      15683.5987
# 49                          Libros y revistas      12388.2035

# %%
#¿Cuál es el número de anuncios por vendedor?

sql = "SELECT id_vendedor, nombre, count(*) as_nb_anuncios FROM anuncio JOIN vendedor USING (id_vendedor)  GROUP BY id_vendedor, nombre ORDER BY count(*) DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#                                             id_vendedor  \
# 0               Desarmaduria Autorey_Región_La Cisterna
# 1                    Carolina fernandez_Región_Santiago
# 2                        Alberto ojeda_XII_Punta Arenas
# 3                   desarmaduriaterracars_Región_Colina
# 4     Ceballos & Jopia Gestión Inmobiliaria SpA_V_Vi...
# ...                                                 ...
# 6693                   josenicolashurtadovera_X_Maullín
# 6694                 Juan Carlos Muñoz_Región_Peñalolén
# 6695                              juan carlos_I_Iquique
# 6696    juan ignacio loureiro caldera_Región_Las Condes
# 6697                      Juan Pablo Rossi_Región_Ñuñoa
#
#                                          nombre  as_nb_anuncios
# 0                          Desarmaduria Autorey             559
# 1                            Carolina fernandez             410
# 2                                 Alberto ojeda             321
# 3                         desarmaduriaterracars             138
# 4     Ceballos & Jopia Gestión Inmobiliaria SpA             102
# ...                                         ...             ...
# 6693                     josenicolashurtadovera               1
# 6694                          Juan Carlos Muñoz               1
# 6695                                juan carlos               1
# 6696              juan ignacio loureiro caldera               1
# 6697                           Juan Pablo Rossi               1
#
# [6698 rows x 3 columns]

# %%
#¿Cuál es el precio promedio de los anuncios según el día de la semana (lunes, martes, miercoles, etc.), por categoria?
sql = "select DAYOFWEEK(fecha_publicacion) as dia,categoria, avg(precio) from anuncio where moneda=\"$\" group by dia, categoria order by avg(precio) desc;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#     dia                       categoria     avg(precio)
# 0     3  Vendo - Comercial e industrial  260790000.0000
# 1     4                 Vendo - Oficina  180000000.0000
# 2     3                    Vendo - Casa  104975976.9018
# 3     4                 Vendo - Terreno   93943243.2432
# 4     4                    Vendo - Casa   81012389.3805
# ..  ...                             ...             ...
# 92    3   Vestuario futura mamá y niños      17971.1765
# 93    3               Libros y revistas      12982.3787
# 94    4                 Otros productos      12676.0377
# 95    4               Libros y revistas      10749.8529
# 96    4   Vestuario futura mamá y niños       5796.6102
#
# [97 rows x 3 columns]

# %% [markdown]
# ### Insertar una columna “Perfil” en la tabla Vendedor. Los Vendedores que publicaron más de 5 anuncios en el último día, tienen un perfil “Pro”, los otros se consideran “Personal”.

# %%
#Modificamos la estructura de la tabla "vendedor"

#sql = "ALTER TABLE vendedor ADD perfil VARCHAR(10);"
#cursor.execute(sql)

# %%
#Pongamos un valor por defecto en la column "perfil"

sql = "UPDATE vendedor SET perfil=\"Personal\";"
cursor.execute(sql)
cursor.execute("COMMIT")

# %%
#Actualizamos la columna "perfil" para los vendedores que publicaron más de 5 anuncios en el último día


sql = "SELECT id_vendedor FROM anuncio JOIN vendedor USING (id_vendedor)  GROUP BY id_vendedor HAVING count(*) >= 5 ORDER BY count(*) DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
#print(df1[:5])

for index,row in df1.iterrows():
    id_vendedor=row[0]
    
    sql = "UPDATE vendedor SET perfil=\"Pro\" WHERE id_vendedor=\""+id_vendedor+"\";"
    cursor.execute(sql)

cursor.execute("COMMIT")

# %%
#¿Cuál es el número de vendedores por tipo de perfil?
sql = "SELECT perfil, count(*) as vendedores FROM vendedor GROUP BY perfil;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#      perfil  vendedores
# 0  Personal        6813
# 1       Pro        1044

# %% [markdown]
# # 4. Visualizaciones de datos en un mapa

# %% [markdown]
# ## 4.1 Shapefile

# %%
shp_path = "./cl_regiones_geo/cl_regiones_geo.shp"
sf = shp.Reader(shp_path, encoding="ISO8859-1")

# %%
len(sf.shapes())
# Out:
# 15

# %%
sf.records()[2]
# Out:
# Record #2: ['02', 'Antofagasta']

# %%
sf.records()[1][1]
# Out:
# 'Tarapaca'

# %%
def read_shapefile(sf):
    """
    Read a shapefile into a Pandas dataframe with a 'coords' 
    column holding the geometry information. This uses the pyshp
    package
    """
    fields = [x[0] for x in sf.fields][1:]
    records = sf.records()
    shps = [s.points for s in sf.shapes()]
    df = pd.DataFrame(columns=fields, data=records)
    df = df.assign(coords=shps)
    return df

# %%
df = read_shapefile(sf)
df.shape
# Out:
# (15, 3)

# %%
df.sample(15)
# Out:
#    ID_2002                                   NOMBRE  \
# 5       05                               Valparaiso
# 2       02                              Antofagasta
# 10      09                             La Araucania
# 11      14                                 Los Rios
# 7       06      Libertador Gral. Bernardo O'Higgins
# 3       03                                  Atacama
# 0       15                       Arica y Parinacota
# 13      11  Aisen del Gral. Carlos Ibañez del Campo
# 14      12     Magallanes y de la Antartica Chileno
# 4       04                                 Coquimbo
# 6       13                Metropolitana de Santiago
# 8       07                                    Maule
# 12      10                                Los Lagos
# 1       01                                 Tarapaca
# 9       08                                   Biobio
#
#                                                coords
# 5   [(-70.319802, -32.274733), (-70.314426, -32.27...
# 2   [(-68.481222, -20.945989), (-68.480813, -20.94...
# 10  [(-71.044287, -38.123172), (-71.029341, -38.13...
# 11  [(-71.967833, -40.63312), (-71.971205, -40.634...
# 7   [(-70.03126, -34.28848), (-70.031713, -34.2923...
# 3   [(-68.544889, -25.298825), (-68.543865, -25.31...
# 0   [(-70.266233, -19.190222), (-70.27196, -19.188...
# 13  [(-72.737018, -43.829555), (-72.738551, -43.82...
# 14  [(-74.704448, -50.202635), (-74.704448, -50.20...
# 4   [(-69.952308, -29.503367), (-69.951567, -29.50...
# 6   [(-70.24362, -33.187388), (-70.242295, -33.184...
# 8   [(-70.363785, -35.003876), (-70.364762, -35.00...
# 12  [(-73.720279, -40.247128), (-73.718843, -40.24...
# 1   [(-70.286169, -19.228974), (-70.130959, -19.15...
# 9   [(-73.684488, -37.367238), (-73.684134, -37.36...

# %%
df[df.NOMBRE == 'Los Rios']
# Out:
#    ID_2002    NOMBRE                                             coords
# 11      14  Los Rios  [(-71.967833, -40.63312), (-71.971205, -40.634...

# %% [markdown]
# ## 4.2 Visualizar el mapa (funciones útiles)

# %% [markdown]
# Tutorial y fuente del código: https://towardsdatascience.com/mapping-geograph-data-in-python-610a963d2d7f

# %%
def calc_color(data, color=None):
        if color   == 1: 
            color_sq =  ['#dadaebFF','#bcbddcF0','#9e9ac8F0',
                        '#807dbaF0','#6a51a3F0','#54278fF0']; 
            colors = 'Purples';
        elif color == 2: 
            color_sq = ['#c7e9b4','#7fcdbb','#41b6c4',
                        '#1d91c0','#225ea8','#253494']; 
            colors = 'YlGnBu';
        elif color == 3: 
            color_sq = ['#f7f7f7','#d9d9d9','#bdbdbd',
                        '#969696','#636363','#252525']; 
            colors = 'Greys';
        elif color == 9: 
            color_sq = ['#ff0000','#ff0000','#ff0000',
                        '#ff0000','#ff0000','#ff0000']
        else:            
            color_sq = ['#ffffd4','#fee391','#fec44f',
                        '#fe9929','#d95f0e','#993404']; 
            colors = 'YlOrBr';
        
        new_data, bins = pd.qcut(data, 6, retbins=True, labels=list(range(6)))
        color_ton = []
        for val in new_data:
            color_ton.append(color_sq[val]) 
        if color != 9:
            colors = sns.color_palette(colors, n_colors=6)
            sns.palplot(colors, 0.6);
            for i in range(6):
                print ("\n"+str(i+1)+': '+str(int(bins[i]))+
                       " => "+str(int(bins[i+1])-1), end =" ")
            print("\n\n   1   2   3   4   5   6")    
        return color_ton, bins;

# %%
def plot_regiones_data(sf, title, regiones, data=None, 
                      color=None, print_id=False):
    '''
    Plot map with selected comunes, using specific color
    '''
    
    color_ton, bins = calc_color(data, color)
    df = read_shapefile(sf)
    region_id = []
    for i in regiones:
        #print(i)
        id = df[df.NOMBRE == i].index.values[0]
        region_id.append(id)
        
        
    y_lim = (-41,-17) # latitude 
    x_lim = (-76, -66) # longitude
    
    plot_map_fill_multiples_ids_tone(sf, title, region_id, 
                                     print_id, 
                                     color_ton, 
                                     bins, 
                                     x_lim = x_lim, 
                                     y_lim = y_lim, 
                                     figsize = (10,25));

# %%
def plot_map_fill_multiples_ids_tone(sf, title, comuna,  
                                     print_id, color_ton, 
                                     bins, 
                                     x_lim = None, 
                                     y_lim = None, 
                                     figsize = (5,12)):
    '''
    Plot map with lim coordinates
    '''
        
    plt.figure(figsize = figsize)
    fig, ax = plt.subplots(figsize = figsize)
    fig.suptitle(title, fontsize=16)
    for shape in sf.shapeRecords():
        x = [i[0] for i in shape.shape.points[:]]
        y = [i[1] for i in shape.shape.points[:]]
        ax.plot(x, y, 'k')
            
    for id in comuna:
        shape_ex = sf.shape(id)
        x_lon = np.zeros((len(shape_ex.points),1))
        y_lat = np.zeros((len(shape_ex.points),1))
        for ip in range(len(shape_ex.points)):
            x_lon[ip] = shape_ex.points[ip][0]
            y_lat[ip] = shape_ex.points[ip][1]
        ax.fill(x_lon,y_lat, color_ton[comuna.index(id)])
        if print_id != False:
            x0 = np.mean(x_lon)
            y0 = np.mean(y_lat)
            plt.text(x0, y0, id, fontsize=10)
    if (x_lim != None) & (y_lim != None):     
        plt.xlim(x_lim)
        plt.ylim(y_lim)

# %% [markdown]
# ## 4.3 Visualizar datos de Yapo en un mapa

# %%
from pandas import DataFrame
#¿Cuál es el número de anuncios Yapo.cl en cada región de Chile ?

sql = "select nombre_region, count(*) as nb_anuncios from vendedor join anuncio using (id_vendedor) where nombre_region != \"Ñuble\" group by nombre_region order by nb_anuncios DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
#              nombre_region  nb_anuncios
# 0            Metropolitana        11942
# 1                   Biobío         1985
# 2               Valparaíso         1783
# 3                Los Lagos         1332
# 4                Araucanía         1118
# 5   Magallanes & Antártica         1051
# 6                 Coquimbo         1010
# 7                O'Higgins          864
# 8              Antofagasta          855
# 9                    Maule          836
# 10                Los Ríos          668
# 11                Tarapacá          310
# 12      Arica & Parinacota          272
# 13                 Atacama          169
# 14                   Aisén          159

# %%
read_shapefile(sf).head(15)
# Out:
#    ID_2002                                   NOMBRE  \
# 0       15                       Arica y Parinacota
# 1       01                                 Tarapaca
# 2       02                              Antofagasta
# 3       03                                  Atacama
# 4       04                                 Coquimbo
# 5       05                               Valparaiso
# 6       13                Metropolitana de Santiago
# 7       06      Libertador Gral. Bernardo O'Higgins
# 8       07                                    Maule
# 9       08                                   Biobio
# 10      09                             La Araucania
# 11      14                                 Los Rios
# 12      10                                Los Lagos
# 13      11  Aisen del Gral. Carlos Ibañez del Campo
# 14      12     Magallanes y de la Antartica Chileno
#
#                                                coords
# 0   [(-70.266233, -19.190222), (-70.27196, -19.188...
# 1   [(-70.286169, -19.228974), (-70.130959, -19.15...
# 2   [(-68.481222, -20.945989), (-68.480813, -20.94...
# 3   [(-68.544889, -25.298825), (-68.543865, -25.31...
# 4   [(-69.952308, -29.503367), (-69.951567, -29.50...
# 5   [(-70.319802, -32.274733), (-70.314426, -32.27...
# 6   [(-70.24362, -33.187388), (-70.242295, -33.184...
# 7   [(-70.03126, -34.28848), (-70.031713, -34.2923...
# 8   [(-70.363785, -35.003876), (-70.364762, -35.00...
# 9   [(-73.684488, -37.367238), (-73.684134, -37.36...
# 10  [(-71.044287, -38.123172), (-71.029341, -38.13...
# 11  [(-71.967833, -40.63312), (-71.971205, -40.634...
# 12  [(-73.720279, -40.247128), (-73.718843, -40.24...
# 13  [(-72.737018, -43.829555), (-72.738551, -43.82...
# 14  [(-74.704448, -50.202635), (-74.704448, -50.20...

# %%
df1.loc[df1.nombre_region == "Metropolitana", "nombre_region"] = "Metropolitana de Santiago"
df1.loc[df1.nombre_region == "Valparaíso", "nombre_region"] = "Valparaiso"
df1.loc[df1.nombre_region == "Biobío", "nombre_region"] = "Biobio"
df1.loc[df1.nombre_region == "Magallanes & Antártica", "nombre_region"] = "Magallanes y de la Antartica Chileno"
df1.loc[df1.nombre_region == "Araucanía", "nombre_region"] = "La Araucania"
df1.loc[df1.nombre_region == "O'Higgins", "nombre_region"] = "Libertador Gral. Bernardo O'Higgins"
df1.loc[df1.nombre_region == "Los Ríos", "nombre_region"] = "Los Rios"
df1.loc[df1.nombre_region == "Tarapacá", "nombre_region"] = "Tarapaca"
df1.loc[df1.nombre_region == "Aisén", "nombre_region"] = "Aisen del Gral. Carlos Ibañez del Campo"
df1.loc[df1.nombre_region == "Arica & Parinacota", "nombre_region"] = "Arica y Parinacota"

# %%
data = df1.nb_anuncios
regiones = df1.nombre_region

print_id = False # The shape id will be printed
color_pallete = 1 # 'Purples'
plot_regiones_data(sf, 'Número de anuncios Yapo.cl por regiones', regiones, data, color_pallete, print_id)
# Out:
# 1: 159 => 283
# 2: 284 => 778
# 3: 779 => 863
# 4: 864 => 1072
# 5: 1073 => 1631
# 6: 1632 => 11941
#
#    1   2   3   4   5   6

# %% [markdown]
# # 5. Visualización de datos en gráficos

# %% [markdown]
# Implementar un script Python para visualizar la distribución de los precios en la categoría “Arriendo - Departamento”.

# %%
pd.options.display.max_colwidth = 300

sql = "select url,titulo,precio from anuncio where moneda = \"$\" and categoria = \"Arriendo - Departamento\" order by precio DESC;"
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1[:20]
# Out:
#                                                                                                                                              url  \
# 0                https://www.yapo.cl/valparaiso/arrendar/ceballos_jopia_vt1128_departamento_villa_alemana_73220955.htm?ca=6_s&oa=73220955&xsp=29
# 1                https://www.yapo.cl/valparaiso/arrendar/ceballos_jopia_vt1128_departamento_villa_alemana_73220955.htm?ca=6_s&oa=73220955&xsp=34
# 2                 https://www.yapo.cl/valparaiso/arrendar/ceballos_jopia_vt1128_departamento_villa_alemana_73220955.htm?ca=6_s&oa=73220955&xsp=4
# 3                 https://www.yapo.cl/valparaiso/arrendar/ceballos_jopia_vt1128_departamento_villa_alemana_73220955.htm?ca=6_s&oa=73220955&xsp=7
# 4                                   https://www.yapo.cl/region_metropolitana/arrendar/busco_departamento_73723075.htm?ca=15_s&oa=73723075&xsp=26
# 5                                   https://www.yapo.cl/region_metropolitana/arrendar/busco_departamento_73723075.htm?ca=15_s&oa=73723075&xsp=31
# 6                                    https://www.yapo.cl/region_metropolitana/arrendar/busco_departamento_73723075.htm?ca=15_s&oa=73723075&xsp=6
# 7                                    https://www.yapo.cl/region_metropolitana/arrendar/busco_departamento_73723075.htm?ca=15_s&oa=73723075&xsp=7
# 8                                    https://www.yapo.cl/region_metropolitana/arrendar/busco_departamento_73723075.htm?ca=15_s&oa=73723075&xsp=9
# 9         https://www.yapo.cl/region_metropolitana/arrendar/espectacular_depto_tipo_loft_en_plaza_brasil_73857644.htm?ca=15_s&oa=73857644&xsp=12
# 10        https://www.yapo.cl/region_metropolitana/arrendar/espectacular_depto_tipo_loft_en_plaza_brasil_73857644.htm?ca=15_s&oa=73857644&xsp=19
# 11         https://www.yapo.cl/region_metropolitana/arrendar/espectacular_depto_tipo_loft_en_plaza_brasil_73857644.htm?ca=15_s&oa=73857644&xsp=3
# 12        https://www.yapo.cl/region_metropolitana/arrendar/espectacular_depto_tipo_loft_en_plaza_brasil_73857644.htm?ca=15_s&oa=73857644&xsp=35
# 13  https://www.yapo.cl/region_metropolitana/arrendar/departamento_escuela_militar_americo_vespuc__8230__73858919.htm?ca=15_s&oa=73858919&xsp=23
# 14                     https://www.yapo.cl/region_metropolitana/arrendar/edificio_club_de_golf___piso_14_69512226.htm?ca=15_s&oa=69512226&xsp=16
# 15                     https://www.yapo.cl/region_metropolitana/arrendar/edificio_club_de_golf___piso_14_69512226.htm?ca=15_s&oa=69512226&xsp=18
# 16                     https://www.yapo.cl/region_metropolitana/arrendar/edificio_club_de_golf___piso_14_69512226.htm?ca=15_s&oa=69512226&xsp=27
# 17                  https://www.yapo.cl/region_metropolitana/arrendar/departamento_golf_norte_las_condes_73858611.htm?ca=15_s&oa=73858611&xsp=33
# 18    https://www.yapo.cl/region_metropolitana/arrendar/departamento_pedro_canisio__av__kennedy_vitacura_73858882.htm?ca=15_s&oa=73858882&xsp=11
# 19  https://www.yapo.cl/region_metropolitana/arrendar/departamento_sector_mall_vivo_los_trapenses__8230__73773647.htm?ca=15_s&oa=73773647&xsp=45
#
#                                               titulo    precio
# 0   Ceballos&Jopia VT1128 Departamento Villa Alemana  57990000
# 1   Ceballos&Jopia VT1128 Departamento Villa Alemana  57990000
# 2   Ceballos&Jopia VT1128 Departamento Villa Alemana  57990000
# 3   Ceballos&Jopia VT1128 Departamento Villa Alemana  57990000
# 4                                 Busco Departamento   2500000
# 5                                 Busco Departamento   2500000
# 6                                 Busco Departamento   2500000
# 7                                 Busco Departamento   2500000
# 8                                 Busco Departamento   2500000
# 9       Espectacular depto tipo loft en plaza brasil   1350000
# 10      Espectacular depto tipo loft en plaza brasil   1350000
# 11      Espectacular depto tipo loft en plaza brasil   1350000
# 12      Espectacular depto tipo loft en plaza brasil   1350000
# 13      Departamento escuela militar/americo vespuc…   1300000
# 14                   Edificio Club de Golf / Piso 14   1250000
# 15                   Edificio Club de Golf / Piso 14   1250000
# 16                   Edificio Club de Golf / Piso 14   1250000
# 17                DEPARTAMENTO GOLF NORTE Las Condes   1150000
# 18  DEPARTAMENTO Pedro Canisio- Av. Kennedy Vitacura    990000
# 19      Departamento sector mall vivo los trapenses…    870000

# %% [markdown]
# Filtramos los 9 primeros valores que no son relevantes y guardamos los valores en un objeto "array":

# %%
x = df1[9:]["precio"].to_numpy()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

sns.set(color_codes=True)

# %%
fig, ax = plt.subplots()
sns.distplot(x, kde=False, norm_hist=False)
ax.set_xlim(0,1400000)
# Out:
# C:\Users\razor\.conda\envs\info133\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0.0, 1400000.0)

# %% [markdown]
# La mayoría de los arriendos de Departamento cuestan entre 200.000 y 400.000 pesos.

# %% [markdown]
# ### ¿Cuál es el precio promedio de los arriendos de Departamento en cada región?

# %%
sql = "select nombre_region, avg(precio) as precio_prom from vendedor join anuncio using (id_vendedor) where categoria=\"Arriendo - Departamento\" and moneda=\"$\" and nombre_region != \"Ñuble\" and precio < 1500000 group by nombre_region order by precio_prom DESC;"
print(sql)
cursor.execute(sql)
df1 = DataFrame(cursor.fetchall())
df1.columns = cursor.column_names
df1
# Out:
# select nombre_region, avg(precio) as precio_prom from vendedor join anuncio using (id_vendedor) where categoria="Arriendo - Departamento" and moneda="$" and nombre_region != "Ñuble" and precio < 1500000 group by nombre_region order by precio_prom DESC;
#              nombre_region  precio_prom
# 0              Antofagasta  493636.3636
# 1                 Tarapacá  465818.1818
# 2       Arica & Parinacota  392727.2727
# 3            Metropolitana  359303.5714
# 4                 Los Ríos  340909.0909
# 5               Valparaíso  331861.7021
# 6   Magallanes & Antártica  326000.0000
# 7                  Atacama  320000.0000
# 8                 Coquimbo  307058.8235
# 9                   Biobío  292348.4848
# 10                   Aisén  292142.8571
# 11               Los Lagos  281000.0000
# 12               Araucanía  250000.0000
# 13               O'Higgins  197777.7778
# 14                   Maule  195000.0000

# %%
df1["precio_prom"] = df1["precio_prom"].astype(int)
df1
# Out:
#              nombre_region  precio_prom
# 0              Antofagasta       493636
# 1                 Tarapacá       465818
# 2       Arica & Parinacota       392727
# 3            Metropolitana       359303
# 4                 Los Ríos       340909
# 5               Valparaíso       331861
# 6   Magallanes & Antártica       326000
# 7                  Atacama       320000
# 8                 Coquimbo       307058
# 9                   Biobío       292348
# 10                   Aisén       292142
# 11               Los Lagos       281000
# 12               Araucanía       250000
# 13               O'Higgins       197777
# 14                   Maule       195000

# %%
df1.loc[df1.nombre_region == "Metropolitana", "nombre_region"] = "Metropolitana de Santiago"
df1.loc[df1.nombre_region == "Valparaíso", "nombre_region"] = "Valparaiso"
df1.loc[df1.nombre_region == "Biobío", "nombre_region"] = "Biobio"
df1.loc[df1.nombre_region == "Magallanes & Antártica", "nombre_region"] = "Magallanes y de la Antartica Chileno"
df1.loc[df1.nombre_region == "Araucanía", "nombre_region"] = "La Araucania"
df1.loc[df1.nombre_region == "O'Higgins", "nombre_region"] = "Libertador Gral. Bernardo O'Higgins"
df1.loc[df1.nombre_region == "Los Ríos", "nombre_region"] = "Los Rios"
df1.loc[df1.nombre_region == "Tarapacá", "nombre_region"] = "Tarapaca"
df1.loc[df1.nombre_region == "Aisén", "nombre_region"] = "Aisen del Gral. Carlos Ibañez del Campo"
df1.loc[df1.nombre_region == "Arica & Parinacota", "nombre_region"] = "Arica y Parinacota"

# %%
data = df1.precio_prom
regiones = df1.nombre_region

print_id = False # The shape id will be printed
color_pallete = 1 # 'Purples'
plot_regiones_data(sf, 'Valores de los arriendos de departamento por regiones (datos Yapo.cl)', regiones, data, color_pallete, print_id)
# Out:
# 1: 195000 => 260332
# 2: 260333 => 292278
# 3: 292279 => 319999
# 4: 320000 => 334876
# 5: 334877 => 381584
# Magallanes y de la Antartica Chileno     MULTIPOLYGON (((-74.70445 -50.20264, -74.70445 -50.20038, -74.70332 -50.19813, -74.70107 -50.19813, -74.70220 -50.19700, -74.69994 -50.19250, -74.69882 -50.19250, -74.69882 -50.19025, -74.69769 -50.18800, -74.69657 -50.18687, -74.69544 -50.18462, -74.69431 -50.18462, -74.69319 -50.18237, -74.693...
#
#                                          precio_prom
# Arica y Parinacota                            392727
# Tarapaca                                      465818
# Antofagasta                                   493636
# Atacama                                       320000
# Coquimbo                                      307058
# Valparaiso                                    331861
# Metropolitana de Santiago                     359303
# Libertador Gral. Bernardo O'Higgins           197777
# Maule                                         195000
# Biobio                                        292348
# La Araucania                                  250000
# Los Rios                                      340909
# Los Lagos                                     281000
# Aisen del Gral. Carlos Ibañez del Campo       292142
# Magallanes y de la Antartica Chileno          326000

# %%
import geopandas as gpd
#df_geo = gpd.read_file(shp_path)
fig, ax = plt.subplots(figsize=(10,20))
result.plot(ax=ax,edgecolor='black', column='precio_prom', cmap='OrRd',legend=True,
        legend_kwds={'label': "Valor arriendo departamento (datos Yapo.cl)",'orientation': "horizontal"})
ax.set_aspect('equal')
plt.show()

# %% [markdown]
# # 8. Palabras claves por categoria

# %%
sql = "SET group_concat_max_len = 65536;"
cursor.execute(sql)
sql = "SELECT categoria, GROUP_CONCAT(descripcion) as texto FROM anuncio GROUP BY categoria;"
cursor.execute(sql)
dfc = DataFrame(cursor.fetchall())
dfc.columns = cursor.column_names

# %%
import spacy

nlp = spacy.load('es_core_news_sm')
spacy_stopwords = spacy.lang.es.stop_words.STOP_WORDS

# %%
dfc["palabras_claves"] = pd.Series("", index=dfc.index)

# %%
from collections import Counter
pd.set_option('display.max_colwidth', 200)

for i in dfc.index:
    doc = nlp(dfc["texto"][i])
    temp = []
    for token in doc:
        if(token.pos_ == "VERB" or token.pos_ == "NOUN" or token.pos_ == "ADJ"):
            temp.append(token.lemma_)
    counts = Counter(temp)
    counts.most_common(10)
    dfc["palabras_claves"][i] = counts.most_common(10)
dfc.drop(columns="texto")
# Out:
#                                     categoria  \
# 0          Accesorios y piezas para vehículos
# 1                   Animales y sus accesorios
# 2                             Arriendo - Casa
# 3           Arriendo - Comercial e industrial
# 4                     Arriendo - Departamento
# 5   Arriendo - Estacionamiento, bodega u otro
# 6                          Arriendo - Oficina
# 7                            Arriendo - Pieza
# 8                          Arriendo - Terreno
# 9              Arriendo de temporada - Cabaña
# 10               Arriendo de temporada - Casa
# 11       Arriendo de temporada - Departamento
# 12           Arte, antigüedades y colecciones
# 13              Audio, TV, video y fotografía
# 14                    Autos, camionetas y 4x4
# 15                  Barcos, lanchas y aviones
# 16          Bicicletas, ciclismo y accesorios
# 17             Bolsos, bisutería y accesorios
# 18                               Busco empleo
# 19                 Buses, camiones y furgones
# 20                                    Calzado
# 21          Celulares, teléfonos y accesorios
# 22              Coches y artículos infantiles
# 23                  Computadores y accesorios
# 24         Consolas, videojuegos y accesorios
# 25            Deportes, gimnasia y accesorios
# 26                          Electrodomésticos
# 27                          Hobbies y outdoor
# 28        Instrumentos musicales y accesorios
# 29          Jardín, herramientas y exteriores
# 30                                   Juguetes
# 31                          Libros y revistas
# 32                           Moda y vestuario
# 33                                      Motos
# 34                                    Muebles
# 35            Música y películas (DVDs, etc.)
# 36        Negocios, maquinaria y construcción
# 37                          Ofertas de empleo
# 38                  Otros artículos del hogar
# 39                            Otros productos
# 40                            Otros vehículos
# 41                            Salud y belleza
# 42                                  Servicios
# 43                               Vendo - Casa
# 44             Vendo - Comercial e industrial
# 45                       Vendo - Departamento
# 46     Vendo - Estacionamiento, bodega u otro
# 47                            Vendo - Oficina
# 48                            Vendo - Terreno
# 49              Vestuario futura mamá y niños
#
#                                                                                                                                                                                    palabras_claves
# 0                                      [(local, 82), (establecer, 57), (DESPACHAMOS, 57), (ACEPTAMOS, 57), (TARJETA, 57), (DIRECCIÓN, 57), (0794, 57), (DESARMADURIA, 57), (solo, 54), (foto, 50)]
# 1                                                           [(centímetro, 43), (perro, 38), (alto, 37), (año, 34), (vender, 31), (entregar, 30), (usar, 29), (tener, 29), (raza, 28), (mesar, 26)]
# 2                                        [(casar, 110), (dormitorio, 101), (arrendar, 73), (bañar, 65), (cocinar, 61), (amplio, 57), (sector, 40), (pisar, 40), (baño, 38), (estacionamiento, 38)]
# 3                                         [(comercial, 72), (local, 64), (arrendar, 52), (bañar, 27), (galería, 27), (estacionamiento, 26), (cuadro, 25), (ubicar, 24), (contar, 23), (tener, 23)]
# 4                                     [(dormitorio, 77), (arrendar, 70), (cocinar, 66), (pisar, 66), (bañar, 57), (estacionamiento, 54), (contar, 51), (común, 50), (departamento, 49), (mes, 42)]
# 5                                                 [(ubicar, 14), (estacionamiento, 11), (﻿1, 10), (mes, 9), (arrendar, 8), (oficina, 7), (seguridad, 7), (común, 7), (metro, 7), (subterráneo, 6)]
# 6                                                     [(oficina, 55), (arrendar, 50), (privar, 47), (edificio, 32), (metro, 31), (baño, 30), (acceso, 30), (bañar, 29), (pisar, 27), (ubicar, 27)]
# 7                                                      [(pieza, 76), (incluir, 61), (personar, 53), (cocinar, 52), (aguar, 48), (compartir, 46), (bañar, 45), (solo, 41), (luz, 38), (cuadro, 36)]
# 8                                                              [(metro, 5), (cuadrar, 3), (favor, 3), (ofertar, 3), (serio, 3), (documentación, 3), (reglar, 3), (ruta, 2), (parque, 2), (Luz, 2)]
# 9                                                        [(pieza, 20), (cama, 16), (equipar, 14), (cabaña, 8), (amplio, 8), (matrimonial, 8), (salar, 8), (estar, 8), (personar, 6), (centrar, 6)]
# 10                                                              [(casar, 3), (sector, 3), (ofrecer, 3), (solo, 3), (hijo, 3), (Tengo, 3), (trabajar, 3), (estable, 3), (tranquilo, 3), (datar, 3)]
# 11                                               [(día, 30), (equipar, 26), (personar, 19), (semana, 18), (departamento, 16), (amoblar, 10), (valor, 10), (ubicar, 9), (habitación, 8), (+569, 8)]
# 12                                                       [(artista, 185), (x, 106), (contar, 82), (cuadro, 74), (pintura, 40), (puntura, 38), (medir, 36), (tener, 36), (aprox, 36), (pintor, 35)]
# 13                                           [(usar, 114), (Lunes, 59), (situación, 58), (implementar, 57), (segundar, 56), (Frente, 56), (Horario, 56), (19:00, 56), (10:00, 56), (Contacto, 56)]
# 14                                              [(trasladar, 50), (discapacidad, 48), (resolución, 48), (solo, 47), (foto, 46), (motor, 42), (día, 40), (tener, 40), (asiento, 37), (crédito, 37)]
# 15  [(motor, 5), (original, 4), (perfecto, 4), (condicionar, 4), (funcionar, 4), (bujíasAlternador, 2), (correasMotor, 2), (arranqueBomba, 2), (direcciónVolanteCarburadorSoportes, 2), (info, 2)]
# 16                                                 [(nuevo, 90), (usar, 82), (bicicleta, 52), (bueno, 50), (marcar, 44), (estar, 39), (vender, 35), (conversable, 33), (preciar, 29), (tener, 26)]
# 17                                                         [(nuevo, 114), (usar, 94), (joya, 91), (buscar, 78), (entregar, 71), (pulsera, 62), (vender, 59), (plata, 53), (hora, 51), (envío, 50)]
# 18                                           [(trabajar, 8), (disponibilidad, 4), (inmediato, 4), (día, 4), (ayudante, 4), (asear, 3), (industrial, 3), (asesorar, 3), (vendedor, 3), (cajero, 3)]
# 19                                                        [(día, 79), (bueno, 56), (estar, 45), (conversable, 44), (vender, 43), (año, 34), (motor, 34), (nuevo, 34), (dueño, 33), (trabajar, 29)]
# 20                                                      [(nuevo, 215), (usar, 210), (número, 97), (vender, 92), (tallar, 90), (original, 73), (bueno, 66), (estar, 60), (cuero, 55), (marcar, 54)]
# 21                                               [(calidad, 113), (teléfono, 107), (proteger, 82), (golpe, 81), (caída, 81), (metro, 71), (cargar, 62), (original, 60), (zona, 56), (carcasa, 56)]
# 22                                                             [(silla, 80), (usar, 79), (bueno, 62), (auto, 60), (estar, 58), (bebé, 55), (excelente, 49), (leche, 42), (nuevo, 38), (coche, 35)]
# 23                                                    [(metro, 77), (REGION, 57), (NUEVO, 42), (usar, 38), (vender, 31), (original, 31), (entregar, 27), (procesador, 26), (x, 23), (memoria, 23)]
# 24                                                      [(usar, 113), (juego, 76), (nuevo, 68), (estar, 67), (vender, 64), (jugar, 58), (bueno, 46), (entregar, 42), (tener, 35), (excelente, 34)]
# 25                                           [(usar, 72), (metro, 53), (nuevo, 50), (ejercicio, 34), (estar, 31), (excelente, 30), (local, 30), (realizar, 28), (entrenamiento, 26), (marcar, 25)]
# 26                                                [(usar, 124), (estar, 56), (bueno, 52), (nuevo, 51), (vender, 50), (funcionar, 50), (centímetro, 47), (marcar, 41), (gas, 40), (domiciliar, 37)]
# 27                                                      [(usar, 48), (rodamiento, 40), (seriar, 36), (centímetro, 31), (x, 27), (producto, 27), (nuevo, 23), (tener, 22), (vaso, 22), (medir, 21)]
# 28                                   [(cuerdo, 137), (guitarra, 78), (gran, 77), (Precio, 66), (instrumento, 63), (necesitar, 63), (accesorio, 61), (consultar, 61), (contar, 59), (variedad, 57)]
# 29                                                     [(usar, 71), (x, 59), (metro, 39), (centímetro, 32), (domiciliar, 31), (vender, 31), (nuevo, 31), (alto, 30), (marcar, 28), (entregar, 27)]
# 30                                                    [(usar, 47), (domiciliar, 42), (metro, 39), (jugar, 32), (tener, 32), (mesar, 28), (niño, 25), (colorir, 24), (figurar, 24), (original, 22)]
# 31                                             [(metro, 329), (bueno, 55), (REGIONES, 40), (entregar, 39), (condicionar, 37), (envia, 34), (Libro, 32), (historia, 26), (librar, 23), (libro, 23)]
# 32                                                      [(usar, 116), (nuevo, 108), (tallar, 82), (estar, 77), (marcar, 70), (bueno, 57), (mujer, 51), (consultar, 46), (color, 45), (vender, 45)]
# 33                                                                [(día, 76), (moto, 74), (año, 57), (papel, 49), (vender, 41), (nuevo, 40), (kilómetro, 38), (solo, 38), (usar, 35), (bueno, 33)]
# 34                                                      [(vender, 99), (bueno, 96), (maderar, 88), (cubrir, 83), (silla, 81), (pieza, 78), (árbol, 76), (estar, 75), (usar, 66), (centímetro, 64)]
# 35                                                 [(través, 88), (época, 86), (Despacho, 72), (bueno, 34), (original, 30), (disco, 29), (interesar, 23), (nuevo, 22), (mensaje, 22), (estar, 22)]
# 36                                                            [(x, 128), (usar, 57), (vivir, 55), (casar, 50), (segundar, 49), (Frente, 49), (Horario, 49), (Lunes, 49), (19:00, 49), (10:00, 49)]
# 37                                            [(trabajar, 69), (experiencia, 67), (día, 39), (necesitar, 36), (personar, 34), (comuna, 34), (ubicar, 30), (cargar, 29), (año, 28), (requerir, 27)]
# 38                                          [(medir, 122), (usar, 86), (segundar, 76), (Frente, 76), (Horario, 76), (Lunes, 76), (19:00, 76), (10:00, 76), (Contacto, 75), (997266439.Debido, 75)]
# 39                                           [(metro, 241), (entregar, 47), (enviar, 43), (domiciliar, 39), (unidad, 31), (kilo, 26), (costo, 26), (católico, 22), (bueno, 20), (condicionar, 20)]
# 40                                                         [(nuevo, 18), (puerta, 16), (eléctrico, 16), (incluir, 16), (gas, 15), (eje, 14), (vender, 13), (bañar, 13), (preciar, 13), (usar, 12)]
# 41                                                         [(local, 62), (usar, 52), (metro, 38), (nivel, 35), (normal, 34), (unidad, 33), (vivir, 32), (medir, 32), (mascarilla, 31), (paso, 30)]
# 42                                        [(realizar, 43), (año, 33), (servicio, 32), (hora, 26), (domiciliar, 26), (trabajar, 24), (experiencia, 22), (tipo, 22), (clase, 22), (instalación, 21)]
# 43                                                [(pisar, 307), (cerámico, 147), (cuadro, 101), (ubicar, 58), (+56, 57), (&, 55), (principal, 47), (techar, 47), (supermercado, 46), (móvil, 46)]
# 44                                                [(contar, 34), (comercial, 23), (ubicar, 23), (gran, 22), (terreno, 20), (usar, 19), (propiedad, 18), (zona, 15), (sector, 15), (ubicación, 14)]
# 45                                  [(pisar, 102), (contar, 79), (dormitorio, 73), (bañar, 50), (estacionamiento, 48), (cocinar, 47), (edificio, 43), (paso, 40), (departamento, 38), (metro, 37)]
# 46                                               [(mayor, 11), (ubicar, 10), (información, 9), (contactar, 9), (casar, 9), (excelente, 7), (entrar, 7), (sector, 7), (reducción, 6), (especie, 6)]
# 47                                          [(estacionamiento, 11), (amplio, 10), (salar, 10), (privar, 9), (propiedad, 8), (paso, 6), (oficina, 6), (entregar, 6), (trabajar, 6), (comerciar, 4)]
# 48                                                    [(aguar, 81), (parcelar, 78), (minuto, 75), (acceso, 68), (sector, 63), (terreno, 62), (luz, 61), (ubicar, 59), (nativo, 46), (caminar, 45)]
# 49                                                             [(niño, 82), (estar, 58), (tallar, 55), (usar, 50), (nuevo, 46), (bueno, 44), (marcar, 34), (entregar, 33), (año, 29), (mesar, 28)]

# %% [markdown]
# # 9. Palabras clave por Región

# %%
sql = "SELECT nombre_region, GROUP_CONCAT(descripcion) as texto FROM vendedor JOIN anuncio USING (id_vendedor) GROUP BY nombre_region;"
cursor.execute(sql)
dfr = DataFrame(cursor.fetchall())
dfr.columns = cursor.column_names

# %%
dfr["palabras_claves"] = pd.Series("", index=dfr.index)

# %%
for i in dfr.index:
    doc = nlp(dfc["texto"][i])
    temp = []
    for token in doc:
        if(token.pos_ == "VERB" or token.pos_ == "NOUN" or token.pos_ == "ADJ"):
            temp.append(token.lemma_)
    counts = Counter(temp)
    counts.most_common(10)
    dfr["palabras_claves"][i] = counts.most_common(1)[0][0]
dfr.drop(columns="texto")
# Out:
#              nombre_region palabras_claves
# 0                    Aisén           local
# 1              Antofagasta      centímetro
# 2                Araucanía           casar
# 3       Arica & Parinacota       comercial
# 4                  Atacama      dormitorio
# 5                   Biobío          ubicar
# 6                 Coquimbo         oficina
# 7                Los Lagos           pieza
# 8                 Los Ríos           metro
# 9   Magallanes & Antártica           pieza
# 10                   Maule           casar
# 11           Metropolitana             día
# 12                   Ñuble         artista
# 13               O'Higgins            usar
# 14                Tarapacá       trasladar
# 15              Valparaíso           motor

# %%
dfr.loc[dfr.nombre_region == "Metropolitana", "nombre_region"] = "Metropolitana de Santiago"
dfr.loc[dfr.nombre_region == "Valparaíso", "nombre_region"] = "Valparaiso"
dfr.loc[dfr.nombre_region == "Biobío", "nombre_region"] = "Biobio"
dfr.loc[dfr.nombre_region == "Magallanes & Antártica", "nombre_region"] = "Magallanes y de la Antartica Chileno"
dfr.loc[dfr.nombre_region == "Araucanía", "nombre_region"] = "La Araucania"
dfr.loc[dfr.nombre_region == "O'Higgins", "nombre_region"] = "Libertador Gral. Bernardo O'Higgins"
dfr.loc[dfr.nombre_region == "Los Ríos", "nombre_region"] = "Los Rios"
dfr.loc[dfr.nombre_region == "Tarapacá", "nombre_region"] = "Tarapaca"
dfr.loc[dfr.nombre_region == "Aisén", "nombre_region"] = "Aisen del Gral. Carlos Ibañez del Campo"
dfr.loc[dfr.nombre_region == "Arica & Parinacota", "nombre_region"] = "Arica y Parinacota"

# %%
result = pd.concat([df_geo.set_index("NOMBRE"), dfr.set_index("nombre_region")], axis=1, join='inner')

# %%
result["center"] = result["geometry"].centroid
points = result.copy()
points.set_geometry("center", inplace = True)

# %%
fig, ax = plt.subplots(figsize=(10,20))
result.plot(ax=ax, edgecolor='lightgrey', color='white', legend=True)
for i in result.index:
    plt.text(result["center"][i].x, result["center"][i].y, result["palabras_claves"][i], fontsize=16)
ax.set_aspect('equal')
plt.show()

# %% [markdown]
# # 10. Analisis de actividad economica

# %% [markdown]
# Seria interesenta comparar los datos de meses anteriores y analizar indicadores como variacion en la cantidad de anuncios y en que categorias se concentran.
#
# Tambien se podrian comparar los cambios en los precios para distintos articulos.
#
# Otro aspectoa a analizar podria ser comparar las regiones que pasaron por estado de cuarentena total versus las que no.
#
# Hay muchos datos utiles que en un sitio como Yapo que nos pueden ayudar a entender mejor el impacto economico de la pandemia en nuestro pais.
